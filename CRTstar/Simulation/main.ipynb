# %%
import sys
import os
from tqdm import trange

sys.path.append(os.path.dirname(os.getcwd()))
sys.path.append(os.path.dirname(os.path.dirname(os.getcwd())))

from MYCRT_package.utils import *
from generate_data_package.utils import *

## Settings using known or unknown parameters
from config_knowA import *
# from config_unknowA import *

# %%
P_list = []
for i in trange(item):
    data = generate_XYZ(i,c,cE,a,aE,aU,n,p,nE,N,A_real,AE_real,N_un,sigz,K,model_y,model_yE,data_type=data_type)
    result = DF_CRT_all(data, i, params, None, False)
    P_list.append(result['P'][0])
print(sum(1 for p in P_list if p < 0.05))
